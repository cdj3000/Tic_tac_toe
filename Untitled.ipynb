# %%
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
data_100= np.random.normal(0,1,100)

# %%
data_sample=np.random.choice(data_100, size=100000,replace=True)

# %%
sns.distplot(data_sample)

# %% [markdown]
# 有一定正态分布的趋势，但不是严格的正态分布。
